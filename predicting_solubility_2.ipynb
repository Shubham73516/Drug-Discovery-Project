# %%
import pandas as pd

# %%
delaney_with_descriptors_url = 'https://raw.githubusercontent.com/dataprofessor/data/master/delaney_solubility_with_descriptors.csv'
dataset = pd.read_csv(delaney_with_descriptors_url)

# %%
dataset
# Out:
#       MolLogP    MolWt  NumRotatableBonds  AromaticProportion   logS
# 0     2.59540  167.850                0.0            0.000000 -2.180
# 1     2.37650  133.405                0.0            0.000000 -2.000
# 2     2.59380  167.850                1.0            0.000000 -1.740
# 3     2.02890  133.405                1.0            0.000000 -1.480
# 4     2.91890  187.375                1.0            0.000000 -3.040
# ...       ...      ...                ...                 ...    ...
# 1139  1.98820  287.343                8.0            0.000000  1.144
# 1140  3.42130  286.114                2.0            0.333333 -4.925
# 1141  3.60960  308.333                4.0            0.695652 -3.893
# 1142  2.56214  354.815                3.0            0.521739 -3.790
# 1143  2.02164  179.219                1.0            0.461538 -2.581
#
# [1144 rows x 5 columns]

# %%
from pycaret.regression import *

# %%
model = setup(data = dataset, target = 'logS', train_size=0.8,)
# Out:
# <style type="text/css">
# #T_6e207_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_6e207">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6e207_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_6e207_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6e207_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6e207_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_6e207_row0_col1" class="data row0 col1" >1637</td>
#     </tr>
#     <tr>
#       <th id="T_6e207_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6e207_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_6e207_row1_col1" class="data row1 col1" >logS</td>
#     </tr>
#     <tr>
#       <th id="T_6e207_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_6e207_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_6e207_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_6e207_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_6e207_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_6e207_row3_col1" class="data row3 col1" >(1144, 5)</td>
#     </tr>
#     <tr>
#       <th id="T_6e207_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_6e207_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_6e207_row4_col1" class="data row4 col1" >(1144, 5)</td>
#     </tr>
#     <tr>
#       <th id="T_6e207_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_6e207_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_6e207_row5_col1" class="data row5 col1" >(915, 5)</td>
#     </tr>
#     <tr>
#       <th id="T_6e207_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_6e207_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_6e207_row6_col1" class="data row6 col1" >(229, 5)</td>
#     </tr>
#     <tr>
#       <th id="T_6e207_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_6e207_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_6e207_row7_col1" class="data row7 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_6e207_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_6e207_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_6e207_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_6e207_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_6e207_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_6e207_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_6e207_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_6e207_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_6e207_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_6e207_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_6e207_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_6e207_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_6e207_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_6e207_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_6e207_row12_col1" class="data row12 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_6e207_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_6e207_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_6e207_row13_col1" class="data row13 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_6e207_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_6e207_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_6e207_row14_col1" class="data row14 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_6e207_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_6e207_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_6e207_row15_col1" class="data row15 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_6e207_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_6e207_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_6e207_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_6e207_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_6e207_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_6e207_row17_col1" class="data row17 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_6e207_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_6e207_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_6e207_row18_col1" class="data row18 col1" >5a30</td>
#     </tr>
#   </tbody>
# </table>

# %%
et = create_model('et')

# %%
tuned_et = tune_model('et', n_iter = 50, optimize = 'mae')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 tuned_et = tune_model('et', n_iter = 50, optimize = 'mae')
#
# File c:\Users\shubh\miniconda3\lib\site-packages\pycaret\utils\generic.py:965, in check_if_global_is_not_none.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     963     if globals_d[name] is None:
#     964         raise ValueError(message)
# --> 965 return func(*args, **kwargs)
#
# File c:\Users\shubh\miniconda3\lib\site-packages\pycaret\regression\functional.py:1205, in tune_model(estimator, fold, round, n_iter, custom_grid, optimize, custom_scorer, search_library, search_algorithm, early_stopping, early_stopping_max_iters, choose_better, fit_kwargs, groups, return_tuner, verbose, tuner_verbose, return_train_score, **kwargs)
#    1013 @check_if_global_is_not_none(globals(), _CURRENT_EXPERIMENT_DECORATOR_DICT)
#    1014 def tune_model(
#    1015     estimator,
#    (...)
#    1033     **kwargs,
#    1034 ):
#    1035     """
#    1036     This function tunes the hyperparameters of a given estimator. The output of
#    1037     this function is a score grid with CV scores by fold of the best selected
#    (...)
#    1202
#    1203     """
# -> 1205     return _CURRENT_EXPERIMENT.tune_model(
#    1206         estimator=estimator,
#    1207         fold=fold,
#    1208         round=round,
#    1209         n_iter=n_iter,
#    1210         custom_grid=custom_grid,
#    1211         optimize=optimize,
#    1212         custom_scorer=custom_scorer,
#    1213         search_library=search_library,
#    1214         search_algorithm=search_algorithm,
#    1215         early_stopping=early_stopping,
#    1216         early_stopping_max_iters=early_stopping_max_iters,
#    1217         choose_better=choose_better,
#    1218         fit_kwargs=fit_kwargs,
#    1219         groups=groups,
#    1220         return_tuner=return_tuner,
#    1221         verbose=verbose,
#    1222         tuner_verbose=tuner_verbose,
#    1223         return_train_score=return_train_score,
#    1224         **kwargs,
#    1225     )
#
# File c:\Users\shubh\miniconda3\lib\site-packages\pycaret\regression\oop.py:1507, in RegressionExperiment.tune_model(self, estimator, fold, round, n_iter, custom_grid, optimize, custom_scorer, search_library, search_algorithm, early_stopping, early_stopping_max_iters, choose_better, fit_kwargs, groups, return_tuner, verbose, tuner_verbose, return_train_score, **kwargs)
#    1315 def tune_model(
#    1316     self,
#    1317     estimator,
#    (...)
#    1335     **kwargs,
#    1336 ):
#    1337     """
#    1338     This function tunes the hyperparameters of a given estimator. The output of
#    1339     this function is a score grid with CV scores by fold of the best selected
#    (...)
#    1504
#    1505     """
# -> 1507     return super().tune_model(
#    1508         estimator=estimator,
#    1509         fold=fold,
#    1510         round=round,
#    1511         n_iter=n_iter,
#    1512         custom_grid=custom_grid,
#    1513         optimize=optimize,
#    1514         custom_scorer=custom_scorer,
#    1515         search_library=search_library,
#    1516         search_algorithm=search_algorithm,
#    1517         early_stopping=early_stopping,
#    1518         early_stopping_max_iters=early_stopping_max_iters,
#    1519         choose_better=choose_better,
#    1520         fit_kwargs=fit_kwargs,
#    1521         groups=groups,
#    1522         return_tuner=return_tuner,
#    1523         verbose=verbose,
#    1524         tuner_verbose=tuner_verbose,
#    1525         return_train_score=return_train_score,
#    1526         **kwargs,
#    1527     )
#
# File c:\Users\shubh\miniconda3\lib\site-packages\pycaret\internal\pycaret_experiment\supervised_experiment.py:1975, in _SupervisedExperiment.tune_model(self, estimator, fold, round, n_iter, custom_grid, optimize, custom_scorer, search_library, search_algorithm, early_stopping, early_stopping_max_iters, choose_better, fit_kwargs, groups, return_tuner, verbose, tuner_verbose, return_train_score, **kwargs)
#    1973 # checking estimator if string
#    1974 if type(estimator) is str:
# -> 1975     raise TypeError(
#    1976         "The behavior of tune_model in version 1.0.1 is changed. Please pass trained model object."
#    1977     )
#    1979 # Check for estimator
#    1980 if not hasattr(estimator, "fit"):
#
# TypeError: The behavior of tune_model in version 1.0.1 is changed. Please pass trained model object.
